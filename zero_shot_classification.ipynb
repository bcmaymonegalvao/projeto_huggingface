# %% [markdown]
# <a href="https://colab.research.google.com/github/bcmaymonegalvao/projeto_huggingface/blob/main/zero_shot_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --force-reinstall transformers tokenizers
# Out:
# ...
#   Using cached transformers-5.13.1-py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached tokenizers-0.23.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.8 kB)
# ...
#   Using cached huggingface_hub-1.23.0-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# ...
#   Using cached regex-2026.7.10-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# ...
#   Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# ...
#   Using cached typer-0.26.8-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached safetensors-0.8.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# ...

# %%
from transformers import pipeline

# %%
# Importe as bibliotecas necessárias
from huggingface_hub import login
from google.colab import userdata

# Recupere o token do Hugging Face das suas variáveis secretas do Colab
HF_TOKEN = userdata.get('HF_TOKEN')

# Faça login no Hugging Face Hub
login(token=HF_TOKEN)

print("Login no Hugging Face Hub realizado com sucesso!")
# Out:
# Login no Hugging Face Hub realizado com sucesso!

# %%
classificador = pipeline(
    'zero-shot-classification',
    model="MoritzLaurer/mDeBERTa-v3-base-mnli-xnli"
)
# Out:
# config.json:   0%|          | 0.00/1.07k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/558M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]

# %%
categorias = ['eletronics', 'food', 'toys', 'books']

# %%
predicao = classificador(
  '''Latest model of smartphone with 5G connectivity and 128GB internal storage''',
  candidate_labels=categorias,
  multi_label=False
)

# %%
predicao
# Out:
# {'sequence': 'Latest model of smartphone with 5G connectivity and 128GB internal storage',
#  'labels': ['eletronics', 'food', 'books', 'toys'],
#  'scores': [0.5169552564620972,
#   0.195449098944664,
#   0.14927180111408234,
#   0.13832375407218933]}

# %%
descricao = '''Este water gel leve e refrescante, proporciona hidratação imediata que ajuda a aliviar o repuxamento e aspereza da pele sensível'''
categorias_candidatas = ['beleza', 'cozinha', 'livros']
resultado = classificador(descricao, categorias_candidatas, multi_label=False)
resultado
# Out:
# {'sequence': 'Este water gel leve e refrescante, proporciona hidratação imediata que ajuda a aliviar o repuxamento e aspereza da pele sensível',
#  'labels': ['beleza', 'cozinha', 'livros'],
#  'scores': [0.8411189913749695, 0.09765227138996124, 0.06122869998216629]}

# %%
import pandas as pd

# %%
resultado = pd.DataFrame(resultado).drop(['sequence'], axis=1)
resultado
# Out:
#     labels    scores
# 0   beleza  0.841119
# 1  cozinha  0.097652
# 2   livros  0.061229

# %%
descricao = '''A fritadeira elétrica sem óleo start fry da elgin possui um design único, capacidade para até 3,5 litros, potência de 1400w e
revestimento antiaderente. Seu sistema de circulação de ar ultrarapido frita e economiza energia. Sua grelha de fritura é removível e super fácil
de limpar. Ela conta com uma proteção contra super aquecimento. Possui controle de temperatura de 80ºc a 200ºc que permite você programar a temperatura
de preparo para cada tipo de alimento, timer para até 60 minutos com aviso sonoro e desligamento automático, assim você pode deixar preparando sua
refeição enquanto realiza outras tarefas.'''

categorias_candidatas = ['beleza', 'cozinha', 'livros']
resultado = classificador(descricao, categorias_candidatas, multi_label=False)
resultado = pd.DataFrame(resultado).drop(['sequence'], axis=1)
resultado
# Out:
#     labels    scores
# 0  cozinha  0.804121
# 1   beleza  0.171961
# 2   livros  0.023918

# %%
dados = pd.read_csv(r"https://raw.githubusercontent.com/bcmaymonegalvao/projeto_huggingface/refs/heads/main/descricoes_produtos.csv")

dados
# Out:
#                                             Descrição
# 0   Liquidificador de alta potência com jarra de v...
# 1   Forno Micro-ondas de 20 litros, com menu desco...
# 2   Máquina de café espresso com reservatório de á...
# 3   Torradeira com capacidade para quatro fatias e...
# 4   Panela elétrica multifuncional que cozinha, as...
# 5   Smartphone com 128GB de armazenamento e câmera...
# 6   Smartwatch monitoramento de passos, frequência...
# 7   Notebook gamer com placa de vídeo potente e te...
# 8   Smartphone com tela super retina XDR de 6,7 po...
# 9   Câmera digital com zoom óptico de 20x e vídeos...
# 10  Fone de ouvido sem fio com cancelamento de ruí...
# 11  Carregador portátil com capacidade de 20000mAh...
# 12  Creme hidratante com ácido hialurônico para to...
# 13  Shampoo fortalecedor com biotina e minerais pa...
# 14  Paleta de maquiagem com 24 cores, incluindo op...
# 15  Perfume feminino com notas de jasmim e sândalo...
# ...

# %%
categorias = ['eletrodomésticos', 'eletrônicos', 'beleza', 'brinquedos']

def categorizar(descricao):
  resultado = classificador(descricao, categorias, multi_label=False)
  categoria_max = max(
      zip(
          resultado['labels'],
          resultado['scores'],
          key=lambda x: x[1]
      )
  )[0]
  return categoria_max

# %%
def categorizar(descricao):
  resultado = classificador(descricao, categorias, multi_label=False)
  categoria_max = max(
      zip(
          resultado['labels'],
          resultado['scores']
      ),
      key=lambda x: x[1]
  )[0]
  return categoria_max

dados['categoria'] = dados['Descrição'].apply(categorizar)
